# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import gym

# env = gym.make('gym_dmc:Manipulator_bring_ball-v1')
env = gym.make('gym_dmc:Pendulum_swingup-v1', frame_skip=4)

# %%
env.render()
# Out:
# <PIL.Image.Image image mode=RGB size=84x84 at 0x10EE2A358>

# %%
env.reset()
for i in range(5):
    import time
    time.sleep(0.1)
    a = 0
    env.step(a)
    env.render('notebook')
# Out:
# <PIL.Image.Image image mode=RGB size=84x84 at 0x111A05EF0>
# <PIL.Image.Image image mode=RGB size=84x84 at 0x111A05E80>
# <PIL.Image.Image image mode=RGB size=84x84 at 0x111A05D68>
# <PIL.Image.Image image mode=RGB size=84x84 at 0x111A057F0>
# <PIL.Image.Image image mode=RGB size=84x84 at 0x12CBE5908>
